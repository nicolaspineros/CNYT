# %% [markdown]
# # Laboratorio 3
# ## Estados con 2 qubits
# ### Septiembre 25 CNYT
# ### Nicolas Piñeros Campo

# %%
# Importaciones
from qiskit import QuantumCircuit #Clase para declarar circuitos
from qiskit import execute #Funcion para ejecutar circuitos cuanticos de manera simulada 
                            #o en computador cuantico real

from qiskit import Aer #Módulo donde podemos acceder al simulador qasm
from qiskit.visualization import plot_histogram, plot_bloch_vector # Función para graficar el output como diagrama de barras
# %matplotlib inline
from math import sqrt, pi
import numpy as np
# Esta último llamado me permite usar la librería mat´plotlib en el Notebook

# %%
circuito_1 = QuantumCircuit(2,1)
circuito_2 = QuantumCircuit(2,1)
circuito_3 = QuantumCircuit(2,2)

# %%
v1 = np.array([[4-2j],
              [9+3j]])
v2 = np.array([[5-3j],
              [1+1j]])

# %%
norma_v1 = np.linalg.norm(v1)
norma_v2 = np.linalg.norm(v2)
v1_normalizado = (1/norma_v1) * v1
v2_normalizado = (1/norma_v2) * v2

# %%
EstadoInicial_v1 = [v1_normalizado[0][0],v1_normalizado[1][0]]
EstadoInicial_v2 = [v2_normalizado[0][0],v2_normalizado[1][0]]

circuito_1.initialize(EstadoInicial_v1,0)
circuito_1.initialize(EstadoInicial_v2,1)
circuito_1.measure(0,0)
circuito_1.draw()
# Out:
#      ┌────────────────────────────────────────────────┐┌─┐
# q_0: ┤ initialize(0.38139+-0.19069j,0.85812+0.28604j) ├┤M├
#      └─┬────────────────────────────────────────────┬─┘└╥┘
# q_1: ──┤ initialize(0.83333+-0.5j,0.16667+0.16667j) ├───╫─
#        └────────────────────────────────────────────┘   ║
# c_0: ═══════════════════════════════════════════════════╩═

# %%
simulador = Aer.get_backend('qasm_simulator')
ejecucion = execute(circuito_1, backend=simulador, shots=1000)
resultado = ejecucion.result()
conteos = resultado.get_counts()
print(conteos)
# Out:
# {'1': 827, '0': 173}

# %%
plot_histogram(conteos)

# %%
EstadoInicial_v1 = [v1_normalizado[0][0],v1_normalizado[1][0]]
EstadoInicial_v2 = [v2_normalizado[0][0],v2_normalizado[1][0]]

circuito_2.initialize(EstadoInicial_v1,0)
circuito_2.initialize(EstadoInicial_v2,1)
circuito_2.measure(0,0)
circuito_2.draw()
# Out:
#      ┌────────────────────────────────────────────────┐┌─┐
# q_0: ┤ initialize(0.38139+-0.19069j,0.85812+0.28604j) ├┤M├
#      └─┬────────────────────────────────────────────┬─┘└╥┘
# q_1: ──┤ initialize(0.83333+-0.5j,0.16667+0.16667j) ├───╫─
#        └────────────────────────────────────────────┘   ║
# c_0: ═══════════════════════════════════════════════════╩═

# %%
simulador = Aer.get_backend('qasm_simulator')
ejecucion = execute(circuito_2, backend=simulador, shots=1000)
resultado = ejecucion.result()
conteos = resultado.get_counts()
print(conteos)
# Out:
# {'1': 835, '0': 165}

# %%
plot_histogram(conteos)

# %%
EstadoInicial_v1 = [v1_normalizado[0][0],v1_normalizado[1][0]]
EstadoInicial_v2 = [v2_normalizado[0][0],v2_normalizado[1][0]]

circuito_3.initialize(EstadoInicial_v1,0)
circuito_3.initialize(EstadoInicial_v2,1)
circuito_3.measure(0,0)
circuito_3.measure(1,1)
circuito_3.draw()
# Out:
#      ┌────────────────────────────────────────────────┐┌─┐
# q_0: ┤ initialize(0.38139+-0.19069j,0.85812+0.28604j) ├┤M├───
#      └─┬────────────────────────────────────────────┬─┘└╥┘┌─┐
# q_1: ──┤ initialize(0.83333+-0.5j,0.16667+0.16667j) ├───╫─┤M├
#        └────────────────────────────────────────────┘   ║ └╥┘
# c_0: ═══════════════════════════════════════════════════╩══╬═
#                                                            ║
# c_1: ══════════════════════════════════════════════════════╩═

# %%
simulador = Aer.get_backend('qasm_simulator')
ejecucion = execute(circuito_3, backend=simulador, shots=1000)
resultado = ejecucion.result()
conteos = resultado.get_counts()
print(conteos)
# Out:
# {'11': 38, '01': 755, '10': 7, '00': 200}

# %%
plot_histogram(conteos)

# %% [markdown]
# **Conclusiones:**
# 1. En el 75.5% de las ejecuciones el qubit de arriba colapsó al estado
#  $|1\rangle$ y el de abajo al estado $|0\rangle$
#
# 2. En el 20% de las ejecuciones el qubit de arriba colapso al estado $|0\rangle$ y el de abajo al estado $|0\rangle$
#
# 3. En el 0.7% de las ejecuciones el qubit de arriba colapso al estado $|0\rangle$ y el de abajo al estado $|1\rangle$
#
# 4. En el 3.8% de las ejecuciones el qubit de arriba colapso al estado $|1\rangle$ y el de abajo al estado $|1\rangle$

# %%
circuito_5 = QuantumCircuit(2,2)
circuito_5.h(0)
circuito_5.cx(0,1)
circuito_5.x(0)

circuito_5.measure(0,0)
circuito_5.measure(1,1)

circuito_5.draw(output = 'mpl')

# %% [markdown]
# **Ejercicio 2**

# %%
circuito = QuantumCircuit(2)
circuito.cx(0,1)
circuito.draw(output = 'mpl')

# %%
backend = Aer.get_backend('unitary_simulator')
result = execute(circuito, backend).result()

print(result.get_unitary(circuito, decimals=3))
# Out:
# [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]]

# %% [markdown]
# ![Punto%203%20lab3.jpeg](attachment:Punto%203%20lab3.jpeg)

# %% [markdown]
# **Ejercico 3. matriz SAWP**

# %%
circuito_s = QuantumCircuit(2)
circuito_s.cx(0,1)
circuito_s.cx(1,0)
circuito_s.cx(0,1)
circuito_s.draw(output = 'mpl')

# %%
backend = Aer.get_backend('unitary_simulator')
result = execute(circuito_s, backend).result()

print(result.get_unitary(circuito_s, decimals=3))
# Out:
# [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]]

# %% [markdown]
# **Ejercicio 3.2 circuito con swaps**

# %%
cqint = QuantumCircuit(4)
cqint.swap(0,2)
cqint.swap(0,3)
cqint.swap(0,1)
cqint.draw(output='mpl')

# %% [markdown]
# De esta forma si {q0,q1,q2,q3} corresponde a {$|a\rangle , |b\rangle , |c\rangle , |d\rangle$} respectivamente entonces los valores resultantes despues de los swaps serian: $$q0 = |b\rangle , q1 = |d\rangle , q2 = |a\rangle , q3 = |c\rangle$$

# %%
def fidelidad(v1, v2):
    '''
    Esta funcion recibe 2 vectores complejos y retorna el cuadrado del modulo de su producto interno
    '''
    return np.abs(np.vdot(v1, v2))**2

# %%
v_mas = np.array([[1/np.sqrt(2)],[1/np.sqrt(2)]])
v_menos = np.array([[1/np.sqrt(2)],[-1/np.sqrt(2)]])
fidelidad(v_mas, v_mas)
# Out:
# 0.9999999999999996

# %%
cqtest = QuantumCircuit(3, 1)
cqtest.h(0)
cqtest.initialize([ev_norm[0][0], ev_norm[1][0]],1)
cqtest.barrier()
cqtest.h(2)
cqtest.cswap(2, 1, 0)
cqtest.h(2)
cqtest.measure(2, 0)
cqtest.draw()
# Out:
#                             ┌───┐                        ░
# q_0: ───────────────────────┤ H ├────────────────────────░───────X─────────
#      ┌──────────────────────┴───┴──────────────────────┐ ░       │
# q_1: ┤ initialize(0.67358+-0.28868j,0.67358+0.096225j) ├─░───────X─────────
#      └─────────────────────────────────────────────────┘ ░ ┌───┐ │ ┌───┐┌─┐
# q_2: ────────────────────────────────────────────────────░─┤ H ├─■─┤ H ├┤M├
#                                                          ░ └───┘   └───┘└╥┘
# c_0: ════════════════════════════════════════════════════════════════════╩═

# %%
simulador = Aer.get_backend('qasm_simulator')
conteos_test = execute(cqtest, backend = simulador, shots=1000).result().get_counts()
plot_histogram(conteos_test)

# %%
estado_variable = np.array([[7 - 3j],[7 + 1j]])
norma = np.linalg.norm(estado_variable)
ev_norm = 1/norma * estado_variable

# %%
ev_norm
# Out:
# array([[0.67357531-0.28867513j],
#        [0.67357531+0.09622504j]])

# %%
fidelidad(v_mas, ev_norm)
# Out:
# 0.9259259259259257

# %% [markdown]
# Realice los conteos con el circuito inicial para ver el numero de veces que obtuve el estad cero, para las fidelidades:
#
# |       Fidelidad      |     Estado variable   | veces estado 0 |
# | :---------           |      ---------        |      --------: |
# |         0.1          |  [[4 - 2j],[-2 + 4j]] |      553       |
# |         0.207        | [[5 - 2j],[-1.1 + 4j]]|      611       |
# |         0.29         |  [[4 - 5j],[3 + 6j]]  |      654       |
# |         0.401        |   [[5 - 5j],[4 + 6j]] |      680       |
# |         0.49         |[[6.5 - 5j],[4.5 + 6j]]|      727       |
# |         0.61         |  [[2 - 2j],[6 + 3j]]  |      809       |
# |         0.78         |  [[8 - 2j],[7 + 6j]]  |      909       |
# |         0.92         |  [[7 - 3j],[7 + 1j]]  |      965       |

# %% [markdown]
# ![Grafica%20Fidelidad.jpeg](attachment:Grafica%20Fidelidad.jpeg)
