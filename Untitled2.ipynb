# %%
# Importaciones
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister #Clase para declarar circuitos
from qiskit import execute #Funcion para ejecutar circuitos cuanticos de manera simulada 
                            #o en computador cuantico real

from qiskit import Aer #Módulo donde podemos acceder al simulador qasm
from qiskit.visualization import plot_histogram # Función para graficar el output como diagrama de barras
# %matplotlib inline
# Esta último llamado me permite usar la librería mat´plotlib en el Notebook

# %%
from math import pi
q = QuantumRegister(1)
c = ClassicalRegister(1)
qc = QuantumCircuit(q, c)
qc.u3(2,5,0, q[0])
qc.measure( q[0], c[0])
qc.draw('mpl')

# %%
simulador = Aer.get_backend('qasm_simulator')
ejecucion = execute(qc, backend=simulador, shots=1000)
resultado = ejecucion.result()
conteos = resultado.get_counts()
print(conteos)
# Out:
# {'1': 683, '0': 317}

# %%
plot_histogram(conteos)

# %%
q1 = QuantumCircuit(2,1)
q1.x(1)
q1.h([0,1])
q1.cx(0,1)
q1.h(0)
q1.measure(0,0)
q1.measure(1,0)
q1.draw(output = 'mpl')

# %%
simulador = Aer.get_backend('qasm_simulator')
ejecucion = execute(q1, backend=simulador, shots=1000)
resultado = ejecucion.result()
conteos = resultado.get_counts()
print(conteos)
# Out:
# {'0': 505, '1': 495}

# %%
plot_histogram(conteos)
